# %%
import pandas as pd
import numpy as np


import matplotlib.pyplot as plt
import seaborn as sns

# %%
D=pd.read_csv("../Housing Prices/train.csv")

# %%
D.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature  \
# 1455         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1456         Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 1457         Lvl    AllPub    ...            0    NaN  GdPrv        Shed
# 1458         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1459         Lvl    AllPub    ...            0    NaN    NaN         NaN
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1455       0      8   2007        WD         Normal     175000
# 1456       0      2   2010        WD         Normal     210000
# 1457    2500      5   2010        WD         Normal     266500
# 1458       0      4   2010        WD         Normal     142125
# 1459       0      6   2008        WD         Normal     147500
#
# [5 rows x 81 columns]

# %%
# D.head()

# %%
fig, ax=plt.subplots(figsize=(40,40))
sns.heatmap(D.corr(),annot=True)
# xlable("D.columns"

# %% [markdown]
# there are a lot of features that are highly correlated. for example first floor area and basement area. what I could do is find correlated features and combine them using factor analysis or partial least squares. Before doing that manually, i'll give it  a go with PCA.
#
#
# Prior to PCA, I should take a look at some key relations, visualise.
#
# another thing I must do is adress data type and encoding.

# %%
sns.regplot(x=D.OverallQual, y=D.SalePrice);
# it seems like there is alinear relation however we have a lot of deviation in quality for each price bar.

# %% [markdown]
# It seems a good idea to manually sort the features and group for plotting purposes and later on to examin correlation. I can do this by simply checking which values correlate but i"l use old school pencil and paper.It got tedious. lol

# %%
def encoder(var):
    return var.astype("category").cat.codes

# %%
Objects=D.columns[D.dtypes==object]
# D[Objects]

# %% [markdown]
# I want to encode all of these. I'll first check which of these has too many categries and needs some outlier fixing etc. All extra categories will go into something like "others". To do this I want to see how it all looks. I am lazy so I am going to try to build a function that plots all of these.

# %%
# fig, ax=plt.subplot()
for col in Objects:
#     for i in range (1,45):
#         plt.subplot(9,5,i)
        sns.catplot(x=col,y="SalePrice", kind="violin",data=D)
# Out:
# /home/charlie/environments/PFDS/lib/python3.6/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
# SaleQuality=D.groupby("SalePrice")["OverallQual"].count()a
fig,ax=plt.subplots(figsize=(20,5))
sns.catplot(x="Neighborhood", y="SalePrice",data=D,ax=ax);

# %%
# SaleQuality=D.groupby("SalePrice")["OverallQual"].count()a
fig,ax=plt.subplots(figsize=(20,5))
sns.catplot(x="Exterior1st", y="SalePrice",data=D,ax=ax);

# %%
# SaleQuality=D.groupby("SalePrice")["OverallQual"].count()a
fig,ax=plt.subplots(figsize=(20,5))
sns.catplot(x="Condition1", y="SalePrice",data=D,ax=ax);

# %%
# SaleQuality=D.groupby("SalePrice")["OverallQual"].count()a
fig,ax=plt.subplots(figsize=(20,5))
sns.catplot(x="Condition2", y="SalePrice",data=D,ax=ax);

# %%
for col in Objects:
#     for i in range (1,45):
#         plt.subplot(9,5,i)
        sns.catplot(x=col,y="SalePrice",data=D)
# Out:
# /home/charlie/environments/PFDS/lib/python3.6/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# From these plot, there are obviously categories with very little data that are oulier, so these will be grouped as others, then there are categories for example in neighbourhood where a bunch of them seem to fall under one price range and others at another sot hese should be grouped accordingly so as to avoid overfitting. again there are categories where the data in one category is very high and others are neglible. We can Observe these by count etc but for now I am just going to drop them. A very important point to note here is that because the whole data set is skewed, its hard to have a good visual estimate. I am going to look for a way to deal with the skewness: ie the bulk of the data in this case being in the range of 100-300k sale price.edit: it turns out that skewed data affects the models, much like I anticipated.

# %%
for col in Objects:
    plt.figure()
    sns.countplot(x=col,data=D)
#         print(col)
# Out:
# /home/charlie/environments/PFDS/lib/python3.6/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
plt.figure()
sns.distplot(D.SalePrice)

# %%
D2=D[D.SalePrice>500000]

# %%
D2.T
# Out:
#                   178      440      691      769      803      898      1046  \
# Id                 179      441      692      770      804      899     1047
# MSSubClass          20       20       60       60       60       20       60
# MSZoning            RL       RL       RL       RL       RL       RL       RL
# LotFrontage         63      105      104       47      107      100       85
# LotArea          17423    15431    21535    53504    13891    12919    16056
# Street            Pave     Pave     Pave     Pave     Pave     Pave     Pave
# Alley              NaN      NaN      NaN      NaN      NaN      NaN      NaN
# LotShape           IR1      Reg      IR1      IR2      Reg      IR1      IR1
# LandContour        Lvl      Lvl      Lvl      HLS      Lvl      Lvl      Lvl
# Utilities       AllPub   AllPub   AllPub   AllPub   AllPub   AllPub   AllPub
# LotConfig      CulDSac   Inside   Corner  CulDSac   Inside   Inside   Inside
# LandSlope          Gtl      Gtl      Gtl      Mod      Gtl      Gtl      Gtl
# Neighborhood   StoneBr  NridgHt  NoRidge  StoneBr  NridgHt  NridgHt  StoneBr
# Condition1        Norm     Norm     Norm     Norm     Norm     Norm     Norm
# Condition2        Norm     Norm     Norm     Norm     Norm     Norm     Norm
# BldgType          1Fam     1Fam     1Fam     1Fam     1Fam     1Fam     1Fam
# HouseStyle      1Story   1Story   2Story   2Story   2Story   1Story   2Story
# OverallQual          9       10       10        8        9        9        9
# OverallCond          5        5        6        5        5        5        5
# YearBuilt         2008     2008     1994     2003     2008     2009     2005
# YearRemodAdd      2009     2008     1995     2003     2009     2010     2006
# RoofStyle          Hip      Hip    Gable      Hip      Hip      Hip      Hip
# RoofMatl       CompShg  CompShg  WdShngl  CompShg  CompShg  CompShg  CompShg
# Exterior1st    VinylSd  VinylSd  HdBoard  CemntBd  VinylSd  VinylSd  CemntBd
# Exterior2nd    VinylSd  VinylSd  HdBoard  Wd Shng  VinylSd  VinylSd  CmentBd
# MasVnrType       Stone    Stone  BrkFace  BrkFace    Stone    Stone    Stone
# MasVnrArea         748      200     1170      603      424      760      208
# ExterQual           Ex       Ex       Ex       Ex       Ex       Ex       Gd
# ExterCond           TA       TA       TA       TA       TA       TA       TA
# Foundation       PConc    PConc    PConc    PConc    PConc    PConc    PConc
# ...                ...      ...      ...      ...      ...      ...      ...
# BedroomAbvGr         1        2        4        4        4        2        4
# KitchenAbvGr         1        1        1        1        1        1        1
# KitchenQual         Ex       Ex       Ex       Ex       Ex       Ex       Ex
# TotRmsAbvGrd         9       10       10       12       12       11       11
# Functional         Typ      Typ      Typ      Mod      Typ      Typ      Typ
# Fireplaces           1        2        2        1        1        2        1
# FireplaceQu         Gd       Gd       Ex       Gd       Gd       Gd       Gd
# GarageType      Attchd   Attchd   Attchd  BuiltIn  BuiltIn   Attchd  BuiltIn
# GarageYrBlt       2009     2008     1994     2003     2009     2009     2005
# GarageFinish       Fin      Fin      Fin      Fin      RFn      Fin      Fin
# GarageCars           3        3        3        3        3        3        3
# GarageArea        1166      672      832      841     1020      820      716
# GarageQual          TA       TA       TA       TA       TA       TA       TA
# GarageCond          TA       TA       TA       TA       TA       TA       TA
# PavedDrive           Y        Y        Y        Y        Y        Y        Y
# WoodDeckSF           0        0      382      503       52        0      214
# OpenPorchSF         60       72       50       36      170       67      108
# EnclosedPorch        0        0        0        0        0        0        0
# 3SsnPorch            0        0        0        0        0        0        0
# ScreenPorch          0      170        0      210      192        0        0
# PoolArea             0        0        0        0        0        0        0
# PoolQC             NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Fence              NaN      NaN      NaN      NaN      NaN      NaN      NaN
# MiscFeature        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# MiscVal              0        0        0        0        0        0        0
# MoSold               7        4        1        6        1        3        7
# YrSold            2009     2009     2007     2010     2009     2010     2006
# SaleType           New       WD       WD       WD      New      New      New
# SaleCondition  Partial   Normal   Normal   Normal  Partial  Partial  Partial
# SalePrice       501837   555000   755000   538000   582933   611657   556581
#
#                   1169     1182
# Id                1170     1183
# MSSubClass          60       60
# MSZoning            RL       RL
# LotFrontage        118      160
# LotArea          35760    15623
# Street            Pave     Pave
# Alley              NaN      NaN
# LotShape           IR1      IR1
# LandContour        Lvl      Lvl
# Utilities       AllPub   AllPub
# LotConfig      CulDSac   Corner
# LandSlope          Gtl      Gtl
# Neighborhood   NoRidge  NoRidge
# Condition1        Norm     Norm
# Condition2        Norm     Norm
# BldgType          1Fam     1Fam
# HouseStyle      2Story   2Story
# OverallQual         10       10
# OverallCond          5        5
# YearBuilt         1995     1996
# YearRemodAdd      1996     1996
# RoofStyle          Hip      Hip
# RoofMatl       CompShg  CompShg
# Exterior1st    HdBoard  Wd Sdng
# Exterior2nd    HdBoard  ImStucc
# MasVnrType     BrkFace     None
# MasVnrArea        1378        0
# ExterQual           Gd       Gd
# ExterCond           Gd       TA
# Foundation       PConc    PConc
# ...                ...      ...
# BedroomAbvGr         4        4
# KitchenAbvGr         1        1
# KitchenQual         Gd       Ex
# TotRmsAbvGrd        10       10
# Functional         Typ      Typ
# Fireplaces           1        2
# FireplaceQu         TA       TA
# GarageType      Attchd   Attchd
# GarageYrBlt       1995     1996
# GarageFinish       Fin      Fin
# GarageCars           3        3
# GarageArea         807      813
# GarageQual          TA       TA
# GarageCond          TA       TA
# PavedDrive           Y        Y
# WoodDeckSF         361      171
# OpenPorchSF         76       78
# EnclosedPorch        0        0
# 3SsnPorch            0        0
# ScreenPorch          0        0
# PoolArea             0      555
# PoolQC             NaN       Ex
# Fence              NaN    MnPrv
# MiscFeature        NaN      NaN
# MiscVal              0        0
# MoSold               7        7
# YrSold            2006     2007
# SaleType            WD       WD
# SaleCondition   Normal  Abnorml
# SalePrice       625000   745000
#
# [81 rows x 9 columns]
