# %%
import pandas as pd
import numpy as np


import matplotlib.pyplot as plt
import seaborn as sns

# %%
D=pd.read_csv("../Housing Prices/train.csv")

# %%
D6=pd.read_csv("../Housing Prices/train.csv")
y=D6.SalePrice.copy()
type(y)
# Out:
# pandas.core.series.Series

# %%
D.columns

# %%
fig, ax=plt.subplots(figsize=(40,40))
sns.heatmap(D.corr(),annot=True)

# %% [markdown]
# there are a lot of features that are highly correlated. for example first floor area and basement area. what I could do is find correlated features and combine them using factor analysis or partial least squares. Before doing that manually, i'll give it  a go with PCA.
#
#
# Prior to PCA, I should take a look at some key relations, visualise.
#
# another thing I must do is adress data type and encoding.

# %%
sns.regplot(x=D.OverallQual, y=D.SalePrice);
# it seems like there is alinear relation however we have a lot of deviation in quality for each price bar.

# %% [markdown]
# It seems a good idea to manually sort the features and group for plotting purposes and later on to examin correlation. I can do this by simply checking which values correlate but i"l use old school pencil and paper.It got tedious. lol

# %%
def encoder(var):
    return var.astype("category").cat.codes

# %%
Objects=D.columns[D.dtypes==object]
# D[Objects]

# %% [markdown]
# I want to encode all of these. I'll first check which of these has too many categries and needs some outlier fixing etc. All extra categories will go into something like "others". To do this I want to see how it all looks. I am lazy so I am going to try to build a function that plots all of these.

# %%
# fig, ax=plt.subplot()
for col in Objects:
#     for i in range (1,45):
        plt.figure
#         plt.subplot(9,5,i)
#         sns.catplot(x=col,y="SalePrice",)
        sns.catplot(x=col,y="SalePrice", kind="box",data=D)
# Out:
# /home/charlie/environments/PFDS/lib/python3.6/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
# SaleQuality=D.groupby("SalePrice")["OverallQual"].count()a
fig,ax=plt.subplots(figsize=(20,5))
sns.countplot(D["Neighborhood"]);

# %%
# SaleQuality=D.groupby("SalePrice")["OverallQual"].count()a
fig,ax=plt.subplots(figsize=(20,5))
sns.catplot(x="Exterior1st", y="SalePrice",data=D,ax=ax);

# %%
# SaleQuality=D.groupby("SalePrice")["OverallQual"].count()a
fig,ax=plt.subplots(figsize=(20,5))
sns.catplot(x="Condition1", y="SalePrice",data=D,ax=ax);

# %%
# SaleQuality=D.groupby("SalePrice")["OverallQual"].count()a
fig,ax=plt.subplots(figsize=(20,5))
sns.catplot(x="Condition2", y="SalePrice",data=D,ax=ax);

# %%
for col in Objects:
#     for i in range (1,45):
#         plt.subplot(9,5,i)
        sns.catplot(x=col,y="SalePrice",data=D)
# Out:
# /home/charlie/environments/PFDS/lib/python3.6/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# From these plot, there are obviously categories with very little data that are oulier, so these will be grouped as others, then there are categories for example in neighbourhood where a bunch of them seem to fall under one price range and others at another sot hese should be grouped accordingly so as to avoid overfitting. again there are categories where the data in one category is very high and others are neglible. We can Observe these by count etc but for now I am just going to drop them. A very important point to note here is that because the whole data set is skewed, its hard to have a good visual estimate. I am going to look for a way to deal with the skewness: ie the bulk of the data in this case being in the range of 100-300k sale price.edit: it turns out that skewed data affects the models, much like I anticipated.

# %%
for col in Objects:
    plt.figure()
    sns.countplot(x=col,data=D)
#         print(col)
# Out:
# /home/charlie/environments/PFDS/lib/python3.6/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
plt.figure()
sns.distplot(D.SalePrice)

# %%
D2=D[D.SalePrice>500000]

# %%
D2.T

# %%
D.isna().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
#                  ...
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageCars          0
# GarageArea          0
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# SalePrice           0
# Length: 81, dtype: int64

# %%
Object3=[]
for col in D.columns:
    if D[col].dtype=='float64' or D[col].dtype== 'int64':
            D[col].fillna(D[col].median(),inplace=True)
            Object3.append(col)
    else:
        D[col].fillna(D[col].value_counts().idxmax(),inplace=True)

# %%
D2=D[Object3].copy()

# %%
D2.drop(['Id','SalePrice'],axis=1,inplace=True)
D2.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2   ...    GarageArea  \
# 0          2003       196.0         706           0   ...           548
# 1          1976         0.0         978           0   ...           460
# 2          2002       162.0         486           0   ...           608
# 3          1970         0.0         216           0   ...           642
# 4          2000       350.0         655           0   ...           836
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 0           0           61              0          0            0         0
# 1         298            0              0          0            0         0
# 2           0           42              0          0            0         0
# 3           0           35            272          0            0         0
# 4         192           84              0          0            0         0
#
#    MiscVal  MoSold  YrSold
# 0        0       2    2008
# 1        0       5    2007
# 2        0       9    2008
# 3        0       2    2006
# 4        0      12    2008
#
# [5 rows x 36 columns]

# %%
from sklearn.preprocessing import StandardScaler
StandardScaler(copy=True, with_mean=True, with_std=True)
scaler = StandardScaler()
D2=scaler.fit_transform(D2)

# %%
# import numpy as np
from sklearn.decomposition import PCA
# X = np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2]])
pca = PCA(n_components=30)
D3=pca.fit_transform(D2)


var=pca.explained_variance_ratio_
var1=np.cumsum(np.round(var,decimals=4)*100)

print(var1)
# Out:
# [19.79 28.69 35.84 41.46 45.56 48.87 52.07 55.22 58.3  61.32 64.23 67.07
#  69.88 72.53 75.08 77.58 79.93 82.19 84.37 86.42 88.29 90.03 91.66 93.16
#  94.36 95.44 96.31 97.09 97.8  98.47]

# %%
plt.plot(var1)

# %%
Object2=['MSZoning','Street','LotShape','LotConfig','Condition1','BldgType','Neighborhood','HouseStyle','Exterior1st','Exterior2nd','BsmtFinType1','Electrical','FireplaceQu','GarageType','SaleType','SaleCondition']

# %%
for col in D.columns:
    if col in Objects and col not in Object2:
        D.drop([col],axis=1,inplace=True)

# %%
D4=D[Object2]

# %%
D4
# Out:
#      MSZoning Street LotShape LotConfig Condition1 BldgType Neighborhood  \
# 0          RL   Pave      Reg    Inside       Norm     1Fam      CollgCr
# 1          RL   Pave      Reg       FR2      Feedr     1Fam      Veenker
# 2          RL   Pave      IR1    Inside       Norm     1Fam      CollgCr
# 3          RL   Pave      IR1    Corner       Norm     1Fam      Crawfor
# 4          RL   Pave      IR1       FR2       Norm     1Fam      NoRidge
# 5          RL   Pave      IR1    Inside       Norm     1Fam      Mitchel
# 6          RL   Pave      Reg    Inside       Norm     1Fam      Somerst
# 7          RL   Pave      IR1    Corner       PosN     1Fam       NWAmes
# 8          RM   Pave      Reg    Inside     Artery     1Fam      OldTown
# 9          RL   Pave      Reg    Corner     Artery   2fmCon      BrkSide
# 10         RL   Pave      Reg    Inside       Norm     1Fam       Sawyer
# 11         RL   Pave      IR1    Inside       Norm     1Fam      NridgHt
# 12         RL   Pave      IR2    Inside       Norm     1Fam       Sawyer
# 13         RL   Pave      IR1    Inside       Norm     1Fam      CollgCr
# 14         RL   Pave      IR1    Corner       Norm     1Fam        NAmes
# 15         RM   Pave      Reg    Corner       Norm     1Fam      BrkSide
# 16         RL   Pave      IR1   CulDSac       Norm     1Fam        NAmes
# 17         RL   Pave      Reg    Inside       Norm   Duplex       Sawyer
# 18         RL   Pave      Reg    Inside       RRAe     1Fam      SawyerW
# 19         RL   Pave      Reg    Inside       Norm     1Fam        NAmes
# 20         RL   Pave      IR1    Corner       Norm     1Fam      NridgHt
# 21         RM   Pave      Reg    Inside       Norm     1Fam       IDOTRR
# 22         RL   Pave      Reg    Inside       Norm     1Fam      CollgCr
# 23         RM   Pave      Reg    Inside       Norm   TwnhsE      MeadowV
# 24         RL   Pave      IR1    Inside       Norm     1Fam       Sawyer
# 25         RL   Pave      Reg    Corner       Norm     1Fam      NridgHt
# 26         RL   Pave      Reg    Corner       Norm     1Fam        NAmes
# 27         RL   Pave      Reg    Inside       Norm     1Fam      NridgHt
# 28         RL   Pave      IR1   CulDSac       Norm     1Fam        NAmes
# 29         RM   Pave      IR1    Inside      Feedr     1Fam      BrkSide
# ...       ...    ...      ...       ...        ...      ...          ...
# 1430       RL   Pave      IR3    Inside       RRAn     1Fam      Gilbert
# 1431       RL   Pave      IR1    Inside       Norm   TwnhsE      NPkVill
# 1432       RL   Pave      Reg    Inside       Norm     1Fam      OldTown
# 1433       RL   Pave      IR1    Inside       Norm     1Fam      Gilbert
# 1434       RL   Pave      Reg    Inside       Norm     1Fam      Mitchel
# 1435       RL   Pave      Reg    Inside       Norm     1Fam        NAmes
# 1436       RL   Pave      Reg       FR2       Norm     1Fam        NAmes
# 1437       RL   Pave      Reg       FR2       Norm     1Fam      NridgHt
# 1438       RM   Pave      Reg    Inside     Artery     1Fam      OldTown
# 1439       RL   Pave      Reg    Inside       Norm     1Fam       NWAmes
# 1440       RL   Pave      IR1    Inside       Norm     1Fam      Crawfor
# 1441       RM   Pave      Reg    Inside       Norm   TwnhsE      CollgCr
# 1442       FV   Pave      Reg    Inside       Norm     1Fam      Somerst
# 1443       RL   Pave      Reg    Inside       Norm     1Fam      BrkSide
# 1444       RL   Pave      Reg       FR2       Norm     1Fam      CollgCr
# 1445       RL   Pave      Reg    Inside       Norm     1Fam       Sawyer
# 1446       RL   Pave      IR1   CulDSac       Norm     1Fam      Mitchel
# 1447       RL   Pave      Reg    Inside       Norm     1Fam      CollgCr
# 1448       RL   Pave      Reg    Inside       Norm     1Fam      Edwards
# 1449       RM   Pave      Reg    Inside       Norm    Twnhs      MeadowV
# 1450       RL   Pave      Reg       FR2       Norm   Duplex        NAmes
# 1451       RL   Pave      Reg    Inside       Norm     1Fam      Somerst
# 1452       RM   Pave      Reg    Inside       Norm   TwnhsE      Edwards
# 1453       RL   Pave      Reg    Inside       Norm     1Fam      Mitchel
# 1454       FV   Pave      Reg    Inside       Norm     1Fam      Somerst
# 1455       RL   Pave      Reg    Inside       Norm     1Fam      Gilbert
# 1456       RL   Pave      Reg    Inside       Norm     1Fam       NWAmes
# 1457       RL   Pave      Reg    Inside       Norm     1Fam      Crawfor
# 1458       RL   Pave      Reg    Inside       Norm     1Fam        NAmes
# 1459       RL   Pave      Reg    Inside       Norm     1Fam      Edwards
#
#      HouseStyle Exterior1st Exterior2nd BsmtFinType1 Electrical FireplaceQu  \
# 0        2Story     VinylSd     VinylSd          GLQ      SBrkr          Gd
# 1        1Story     MetalSd     MetalSd          ALQ      SBrkr          TA
# 2        2Story     VinylSd     VinylSd          GLQ      SBrkr          TA
# 3        2Story     Wd Sdng     Wd Shng          ALQ      SBrkr          Gd
# 4        2Story     VinylSd     VinylSd          GLQ      SBrkr          TA
# 5        1.5Fin     VinylSd     VinylSd          GLQ      SBrkr          Gd
# 6        1Story     VinylSd     VinylSd          GLQ      SBrkr          Gd
# 7        2Story     HdBoard     HdBoard          ALQ      SBrkr          TA
# 8        1.5Fin     BrkFace     Wd Shng          Unf      FuseF          TA
# 9        1.5Unf     MetalSd     MetalSd          GLQ      SBrkr          TA
# 10       1Story     HdBoard     HdBoard          Rec      SBrkr          Gd
# 11       2Story     WdShing     Wd Shng          GLQ      SBrkr          Gd
# 12       1Story     HdBoard     Plywood          ALQ      SBrkr          Gd
# 13       1Story     VinylSd     VinylSd          Unf      SBrkr          Gd
# 14       1Story     MetalSd     MetalSd          BLQ      SBrkr          Fa
# 15       1.5Unf     Wd Sdng     Wd Sdng          Unf      FuseA          Gd
# 16       1Story     Wd Sdng     Wd Sdng          ALQ      SBrkr          TA
# 17       1Story     MetalSd     MetalSd          Unf      SBrkr          Gd
# 18       1Story     VinylSd     VinylSd          GLQ      SBrkr          Gd
# 19       1Story     BrkFace     Plywood          LwQ      SBrkr          Gd
# 20       2Story     VinylSd     VinylSd          Unf      SBrkr          Gd
# 21       1.5Unf     Wd Sdng     Wd Sdng          Unf      FuseF          Gd
# 22       1Story     VinylSd     VinylSd          Unf      SBrkr          Gd
# 23       1Story     CemntBd     CmentBd          GLQ      SBrkr          TA
# 24       1Story     Plywood     Plywood          Rec      SBrkr          TA
# 25       1Story     VinylSd     VinylSd          Unf      SBrkr          Gd
# 26       1Story     Wd Sdng     Wd Sdng          BLQ      SBrkr          Gd
# 27       1Story     VinylSd     VinylSd          GLQ      SBrkr          Gd
# 28       1Story     MetalSd     MetalSd          BLQ      SBrkr          Gd
# 29       1Story     MetalSd     MetalSd          Unf      SBrkr          Gd
# ...         ...         ...         ...          ...        ...         ...
# 1430     2Story     VinylSd     VinylSd          Unf      SBrkr          Gd
# 1431     1Story     Plywood     Plywood          LwQ      SBrkr          Gd
# 1432     1Story     Wd Sdng     Wd Sdng          Unf      SBrkr          Gd
# 1433     2Story     VinylSd     VinylSd          Unf      SBrkr          TA
# 1434     1Story     BrkFace     BrkFace          ALQ      SBrkr          Gd
# 1435     1Story     Wd Sdng     Wd Sdng          Unf      SBrkr          Gd
# 1436     1Story     HdBoard     HdBoard          ALQ      SBrkr          Gd
# 1437     1Story     VinylSd     VinylSd          GLQ      SBrkr          Gd
# 1438     1Story     MetalSd     MetalSd          GLQ      FuseA          Gd
# 1439       SLvl     HdBoard     HdBoard          GLQ      SBrkr          TA
# 1440     2.5Fin     MetalSd     MetalSd          Unf      SBrkr          Gd
# 1441     1Story     VinylSd     VinylSd          GLQ      SBrkr          TA
# 1442     2Story     VinylSd     VinylSd          GLQ      SBrkr          Ex
# 1443     1.5Unf     Wd Sdng     Wd Sdng          Unf      FuseF          Gd
# 1444     1Story     VinylSd     VinylSd          Unf      SBrkr          Gd
# 1445     SFoyer     VinylSd     VinylSd          LwQ      SBrkr          Gd
# 1446     1Story     HdBoard     HdBoard          Rec      SBrkr          Gd
# 1447     2Story     VinylSd     VinylSd          GLQ      SBrkr          TA
# 1448     2Story     MetalSd     HdBoard          Unf      SBrkr          Gd
# 1449     SFoyer     CemntBd     CmentBd          GLQ      SBrkr          Gd
# 1450     2Story     VinylSd     VinylSd          Unf      SBrkr          Gd
# 1451     1Story     CemntBd     CmentBd          Unf      SBrkr          Gd
# 1452       SLvl     VinylSd     VinylSd          GLQ      SBrkr          Gd
# 1453     1Story     VinylSd     VinylSd          Unf      SBrkr          Gd
# 1454     1Story     VinylSd     VinylSd          GLQ      SBrkr          Gd
# 1455     2Story     VinylSd     VinylSd          Unf      SBrkr          TA
# 1456     1Story     Plywood     Plywood          ALQ      SBrkr          TA
# 1457     2Story     CemntBd     CmentBd          GLQ      SBrkr          Gd
# 1458     1Story     MetalSd     MetalSd          GLQ      FuseA          Gd
# 1459     1Story     HdBoard     HdBoard          BLQ      SBrkr          Gd
#
#      GarageType SaleType SaleCondition
# 0        Attchd       WD        Normal
# 1        Attchd       WD        Normal
# 2        Attchd       WD        Normal
# 3        Detchd       WD       Abnorml
# 4        Attchd       WD        Normal
# 5        Attchd       WD        Normal
# 6        Attchd       WD        Normal
# 7        Attchd       WD        Normal
# 8        Detchd       WD       Abnorml
# 9        Attchd       WD        Normal
# 10       Detchd       WD        Normal
# 11      BuiltIn      New       Partial
# 12       Detchd       WD        Normal
# 13       Attchd      New       Partial
# 14       Attchd       WD        Normal
# 15       Detchd       WD        Normal
# 16       Attchd       WD        Normal
# 17      CarPort       WD        Normal
# 18       Detchd       WD        Normal
# 19       Attchd      COD       Abnorml
# 20      BuiltIn      New       Partial
# 21       Attchd       WD        Normal
# 22       Attchd       WD        Normal
# 23       Attchd       WD        Normal
# 24       Attchd       WD        Normal
# 25       Attchd       WD        Normal
# 26       Detchd       WD        Normal
# 27       Attchd       WD        Normal
# 28       Attchd       WD        Normal
# 29       Detchd       WD        Normal
# ...         ...      ...           ...
# 1430    BuiltIn       WD        Normal
# 1431     Attchd       WD        Normal
# 1432     Detchd       WD        Normal
# 1433     Attchd       WD        Normal
# 1434     Attchd       WD        Normal
# 1435     Attchd      COD       Abnorml
# 1436     Detchd       WD        Normal
# 1437     Attchd      New       Partial
# 1438     Attchd       WD        Normal
# 1439     Attchd       WD        Normal
# 1440     Detchd       WD        Normal
# 1441     Attchd       WD        Normal
# 1442     Attchd       WD        Normal
# 1443     Detchd       WD        Normal
# 1444     Attchd       WD        Normal
# 1445     Detchd       WD        Normal
# 1446     Attchd       WD        Normal
# 1447     Attchd       WD        Normal
# 1448     Detchd       WD        Normal
# 1449     Attchd       WD       Abnorml
# 1450     Attchd       WD        Normal
# 1451     Attchd      New       Partial
# 1452    Basment       WD        Normal
# 1453     Attchd       WD       Abnorml
# 1454     Attchd       WD        Normal
# 1455     Attchd       WD        Normal
# 1456     Attchd       WD        Normal
# 1457     Attchd       WD        Normal
# 1458     Attchd       WD        Normal
# 1459     Attchd       WD        Normal
#
# [1460 rows x 16 columns]

# %%
D4.LotShape.replace(['IR2','IR3'], 'other', inplace=True)
# Out:
# /home/charlie/environments/PFDS/lib/python3.6/site-packages/pandas/core/generic.py:5890: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
S=D4.Condition1.value_counts()<100.

D4.Condition1.replace(['Feedr','Artery','RRAn','PosN','RRAe','PosA','RRNn','RRNe'],'other',inplace=True)
# S.index
# Out:
# /home/charlie/environments/PFDS/lib/python3.6/site-packages/pandas/core/generic.py:5890: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
D4.Exterior1st.replace(['CemntBd','BrkFace','WdShing','Stucco','AsbShng','BrkComm','Stone','AsphShn','CBlock','ImStucc'],'other',inplace=True)
# Out:
# /home/charlie/environments/PFDS/lib/python3.6/site-packages/pandas/core/generic.py:5890: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
D4.Exterior2nd.value_counts()
D4.Exterior2nd.replace(['CemntBd','BrkFace','Wd Shng','Stucco','AsbShng','Brk Cmn','Stone','AsphShn','CBlock','other'],'other',inplace=True)
# Out:
# /home/charlie/environments/PFDS/lib/python3.6/site-packages/pandas/core/generic.py:5890: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
D4.Electrical.replace(['FuseA','FuseF','FuseP','Mix'],'other',inplace=True)
# Out:
# /home/charlie/environments/PFDS/lib/python3.6/site-packages/pandas/core/generic.py:5890: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
D4.GarageType.replace(['BuiltIn','Basment','CarPort','2Types'],'other',inplace=True)
# Out:
# /home/charlie/environments/PFDS/lib/python3.6/site-packages/pandas/core/generic.py:5890: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
D4.SaleType.replace(['COD','ConLD','ConLw','ConLi','CWD','Oth','Con'],'other',inplace=True)
# Out:
# /home/charlie/environments/PFDS/lib/python3.6/site-packages/pandas/core/generic.py:5890: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
D4.SaleCondition.replace(['Family','Alloca','AdjLand'],'other',inplace=True)
# Out:
# /home/charlie/environments/PFDS/lib/python3.6/site-packages/pandas/core/generic.py:5890: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
D3

# %%
# for col in Objects2:
for col in D4:
    D4[col]=encoder(D4[col])
# Out:
# /home/charlie/environments/PFDS/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
D5=pd.concat([D3,D4],axis=1)

# %%
D3=pd.DataFrame(D3)

# %% [markdown]
# D3

# %%
D3
# Out:
#             0         1         2         3         4         5         6   \
# 0     1.466021  0.375461 -1.698616 -1.935831  0.530367 -1.219198 -0.818926
# 1    -0.032837 -1.058352  1.259901 -0.039478 -1.734416  0.335394  3.477630
# 2     1.652691  0.252552 -1.475425 -1.374305 -0.129607  0.322096 -0.481370
